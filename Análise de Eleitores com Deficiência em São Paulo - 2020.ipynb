# %% [markdown]
# # Tema: Análise de Eleitores com Deficiência em São Paulo - 2020
#
# **Dupla: Bryan Romero Ribeiro, Raphael Lisboa do Prado**

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
df = pd.read_csv('C:/Users/Notebook Bryan/CursoPyLadiesSP-master/.ipynb_checkpoints/perfil_eleitor_deficiencia_2020_SP.csv',header=0,encoding='ISO-8859-1',delimiter=';')

# %%
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  SQ_ELEITOR SG_UF  CD_MUNICIPIO  \
# 307016  01/08/2020   13:21:54         2020    29259376    SP         70718
# 244525  01/08/2020   13:21:54         2020   342041818    SP         67130
# 38139   01/08/2020   13:21:54         2020   354806716    SP         64777
# 150047  01/08/2020   13:21:54         2020   389649159    SP         67172
# 343640  01/08/2020   13:21:54         2020   301749057    SP         71072
# 97289   01/08/2020   13:21:54         2020    37476145    SP         70297
# 175113  01/08/2020   13:21:54         2020   378439025    SP         63134
# 197499  01/08/2020   13:21:54         2020   419905899    SP         70718
# 407380  01/08/2020   13:21:54         2020   389497408    SP         70572
# 133707  01/08/2020   13:21:54         2020   336104149    SP         62995
#
#                    NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 307016                   SANTOS                     0        Sem biometria
# 244525          MOGI DAS CRUZES                     0        Sem biometria
# 38139                 GUARULHOS                     0        Sem biometria
# 150047               MOGI MIRIM                     0        Sem biometria
# 343640                SÃO PAULO                     0        Sem biometria
# 97289   SANTA CRUZ DO RIO PARDO                     0        Sem biometria
# 175113              CARAPICUÍBA                     0        Sem biometria
# 197499                   SANTOS                     0        Sem biometria
# 407380              SANTO ANDRÉ                     0        Sem biometria
# 133707                 CANANÉIA                     0        Sem biometria
#
#         NR_ZONA  ...  DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  \
# 307016      118  ...  MASCULINO                5           VIÚVO
# 244525      319  ...  MASCULINO                1        SOLTEIRO
# 38139       393  ...  MASCULINO                3          CASADO
# 150047       75  ...   FEMININO                1        SOLTEIRO
# 343640      320  ...  MASCULINO                1        SOLTEIRO
# 97289       114  ...  MASCULINO                1        SOLTEIRO
# 175113      303  ...  MASCULINO                3          CASADO
# 197499      118  ...   FEMININO                1        SOLTEIRO
# 407380      156  ...   FEMININO                3          CASADO
# 133707       36  ...   FEMININO                1        SOLTEIRO
#
#         CD_FAIXA_ETARIA                 DS_FAIXA_ETARIA  CD_GRAU_ESCOLARIDADE  \
# 307016             6569  65 a 69 anos                                       6
# 244525             6064  60 a 64 anos                                       6
# 38139              6064  60 a 64 anos                                       3
# 150047             6064  60 a 64 anos                                       1
# 343640             6064  60 a 64 anos                                       8
# 97289              6569  65 a 69 anos                                       2
# 175113             6569  65 a 69 anos                                       3
# 197499             2529  25 a 29 anos                                       3
# 407380             7074  70 a 74 anos                                       4
# 133707             4044  40 a 44 anos                                       3
#
#                  DS_GRAU_ESCOLARIDADE  ST_ELEITOR_BIOMETRIA  \
# 307016          ENSINO MÉDIO COMPLETO                     N
# 244525          ENSINO MÉDIO COMPLETO                     S
# 38139   ENSINO FUNDAMENTAL INCOMPLETO                     S
# 150047                     ANALFABETO                     S
# 343640              SUPERIOR COMPLETO                     S
# 97289                    LÊ E ESCREVE                     N
# 175113  ENSINO FUNDAMENTAL INCOMPLETO                     S
# 197499  ENSINO FUNDAMENTAL INCOMPLETO                     S
# 407380    ENSINO FUNDAMENTAL COMPLETO                     S
# 133707  ENSINO FUNDAMENTAL INCOMPLETO                     S
#
#        CD_TIPO_DEFICIENCIA                   DS_TIPO_DEFICIENCIA
# 307016                   2              DEFICIÊNCIA DE LOCOMOÇÃO
# 244525                   3                                OUTROS
# 38139                    3                                OUTROS
# 150047                   1                    DEFICIÊNCIA VISUAL
# 343640                   2              DEFICIÊNCIA DE LOCOMOÇÃO
# 97289                    4  DIFICULDADE PARA O EXERCÍCIO DO VOTO
# 175113                   2              DEFICIÊNCIA DE LOCOMOÇÃO
# 197499                   3                                OUTROS
# 407380                   2              DEFICIÊNCIA DE LOCOMOÇÃO
# 133707                   3                                OUTROS
#
# [10 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444130 entries, 0 to 444129
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DT_GERACAO            444130 non-null  object
#  1   HH_GERACAO            444130 non-null  object
#  2   ANO_ELEICAO           444130 non-null  int64
#  3   SQ_ELEITOR            444130 non-null  int64
#  4   SG_UF                 444130 non-null  object
#  5   CD_MUNICIPIO          444130 non-null  int64
#  6   NM_MUNICIPIO          444130 non-null  object
#  7   CD_MUN_SIT_BIOMETRIA  444130 non-null  int64
#  8   DS_MUN_SIT_BIOMETRIA  444130 non-null  object
#  9   NR_ZONA               444130 non-null  int64
#  10  NR_SECAO              444130 non-null  int64
#  11  CD_GENERO             444130 non-null  int64
#  12  DS_GENERO             444130 non-null  object
#  13  CD_ESTADO_CIVIL       444130 non-null  int64
#  14  DS_ESTADO_CIVIL       444130 non-null  object
#  15  CD_FAIXA_ETARIA       444130 non-null  int64
#  16  DS_FAIXA_ETARIA       444130 non-null  object
#  17  CD_GRAU_ESCOLARIDADE  444130 non-null  int64
#  18  DS_GRAU_ESCOLARIDADE  444130 non-null  object
#  19  ST_ELEITOR_BIOMETRIA  444130 non-null  object
#  20  CD_TIPO_DEFICIENCIA   444130 non-null  int64
#  21  DS_TIPO_DEFICIENCIA   444130 non-null  object
# dtypes: int64(11), object(11)
# memory usage: 55.9+ MB
